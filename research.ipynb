# %%
import pandas as pd

# %%
df_crovoc_labels = pd.read_json('./crovoc_labels.json')

# %%
df_crovoc_labels
# Out:
#                    32768    32769    32770       32771    32772    32773  \
# similar_terms         []       []       []          []       []       []
# rank                term     term     term        term     term     term
# thesaurus          28349    28349    28349       28349    28349    28349
# id                 32768    32769    32770       32771    32772    32773
# name              korana   dinara  biokovo  plješivica  svilaja     učka
# micro_thesaurus    32675    32676    32676       32676    32676    32676
# parents          [32675]  [32676]  [32676]     [32676]  [32676]  [32676]
#
#                    32774     32775      32776    10924  ...    10919  \
# similar_terms         []        []         []       []  ...       []
# rank                term      term       term     term  ...     term
# thesaurus          28349     28349      28349    28349  ...    28349
# id                 32774     32775      32776    10924  ...    10919
# name               mosor  ćićarija  ivanščica  jarmina  ...  ivanska
# micro_thesaurus    32676     32676      32676    32669  ...    32669
# parents          [32676]   [32676]    [32676]  [32669]  ...  [32669]
#
#                                      32750              32751      10920  \
# similar_terms                           []                 []         []
# rank                                  term               term       term
# thesaurus                             6022               6022      28349
# id                                   32750              32751      10920
# name             zadarsko-kninska županija  šibenska županija  jabukovac
# micro_thesaurus                      33026              33026      32669
# parents                            [14973]            [14973]    [32669]
#
#                                             32761  \
# similar_terms                                  []
# rank                                         term
# thesaurus                                    6022
# id                                          32761
# name             ministarstvo prosvjete i kulture
# micro_thesaurus                             32851
# parents                                   [32356]
#
#                                                              32762    8191   \
# similar_terms                                                   []       []
# rank                                                          term     term
# thesaurus                                                     6022    28349
# id                                                           32762     8191
# name             ministarstvo zaštite okoliša, prostornog uređe...   jabuka
# micro_thesaurus                                              32851    32669
# parents                                                    [32356]  [32669]
#
#                                       32764                   32766    32767
# similar_terms                            []                      []       []
# rank                                   term                    term     term
# thesaurus                              6022                   28349    28349
# id                                    32764                   32766    32767
# name             ministarstvo privatizacije  lonjsko-ilovska zavala     mura
# micro_thesaurus                       32851                   32666    32675
# parents                             [32356]                 [35537]  [32675]
#
# [7 rows x 8342 columns]

# %%
df_revised = df_crovoc_labels.transpose().reset_index()

# %%
sum(df_revised['parents'] == df_revised['id'])
# Out:
# 0

# %%
df_dataset = pd.read_json('./dataset.json')

# %%
df_dataset
# Out:
#          odluka o usklađivanju novčanih naknada za tjelesno oštećenje od 1. siječnja 1990.  \
# title     odluka o usklađivanju novčanih naknada za tjel...
# text      SAMOUPRAVNA INTERESNA ZAJEDNICA MIROVINSKOG I ...
# labels                                         [3562, 1436]
# filename                                       NN034535.xml
#
#          uredba o kriterijima za utvrđivanje korisnika i načinu raspodjele dijela prihoda od igara na sreću za 2011. godinu  \
# title     uredba o kriterijima za utvrđivanje korisnika ...
# text       \nVLADA REPUBLIKE HRVATSKE\n611\nNa temelju č...
# labels                                    [305, 4730, 2719]
# filename                                       NN038327.xml
#
#          odluka o davanju potpore za rast i razvoj malog gospodarstva  \
# title     odluka o davanju potpore za rast i razvoj malo...
# text      MINISTARSTVO GOSPODARSTVA\nNa temelju Ugovora ...
# labels                             [4368, 763, 27189, 1726]
# filename                                       NN023888.xml
#
#          odluka o davanju suglasnosti na financijski plan za 1998. godinu hrvatskog zavoda za zdravstveno osiguranje  \
# title     odluka o davanju suglasnosti na financijski pl...
# text      ZASTUPNIČKI DOM HRVATSKOGA DRŽAVNOG SABORA\nNa...
# labels                                    [305, 1858, 2013]
# filename                                       NN011746.xml
#
#          odluka o katastarskoj izmjeri na području grada visa za dio katastarske općine vis  \
# title     odluka o katastarskoj izmjeri na području grad...
# text       \nDRŽAVNA GEODETSKA UPRAVA\n1391\nNa temelju ...
# labels                                               [4910]
# filename                                       NN032685.xml
#
#          odluka o visini dnevnice za službeno putovanje i visini naknada za korisnike koji se financiraju iz sredstava državnog proračuna  \
# title     odluka o visini dnevnice za službeno putovanje...
# text      ODBOR ZA IZBOR, IMENOVANJA I ADMINISTRATIVNE P...
# labels                                   [779, 42460, 2719]
# filename                                       NN014897.xml
#
#                    tehnički propis za betonske konstrukcije  \
# title              tehnički propis za betonske konstrukcije
# text       \nMINISTARSTVO ZAŠTITE OKOLIŠA, PROSTORNOG UR...
# labels                               [5960, 977, 981, 4359]
# filename                                       NN033888.xml
#
#                   odluka o određivanju osjetljivih područja  \
# title             odluka o određivanju osjetljivih područja
# text       \nVLADA REPUBLIKE HRVATSKE\n2310\nNa temelju ...
# labels                                   [1730, 811, 33173]
# filename                                       NN035662.xml
#
#          odluka o diskontnoj (eskontnoj) stopi hrvatske narodne banke  \
# title     odluka o diskontnoj (eskontnoj) stopi hrvatske...
# text      HRVATSKA NARODNA BANKA\n3753\nNa temelju člank...
# labels                                         [1120, 1442]
# filename                                       NN028320.xml
#
#          odluka o davanju suglasnosti na financijski plan agencije za upravljanje državnom imovinom za 2013. godinu i projekcije za 2014. i 2015. godinu  \
# title     odluka o davanju suglasnosti na financijski pl...
# text      139 15.12.2012 Odluka o davanju suglasnosti na...
# labels                                    [305, 1858, 2013]
# filename                                       NN042554.xml
#
#           ...  \
# title     ...
# text      ...
# labels    ...
# filename  ...
#
#          ugovor između vlade republike hrvatske i židovske vjerske zajednice bet israel u hrvatskoj o pitanjima od zajedničkog interesa  \
# title     ugovor između vlade republike hrvatske i židov...
# text       \nVLADA REPUBLIKE HRVATSKE\n55\nNa temelju čl...
# labels                                         [2337, 3290]
# filename                                       NN040566.xml
#
#          metodološke osnove za prikupljanje podataka u statistici mlijeka i mliječnih proizvoda  \
# title     metodološke osnove za prikupljanje podataka u ...
# text       \nDRŽAVNI ZAVOD ZA STATISTIKU\n805\nNa temelj...
# labels                              [2624, 3610, 2730, 499]
# filename                                       NN043254.xml
#
#          odluka o programu i načinu provjere stručne osposobljenosti nadzornika koji obavljaju poslove kontrole osovinskog opterećenja, ukupne mase i dimenzija vozila u prometu na cestama  \
# title     odluka o programu i načinu provjere stručne os...
# text      HRVATSKE CESTE\n1607\nNa temelju članka 17. st...
# labels                  [5640, 5960, 3342, 1748, 3645, 415]
# filename                                       NN029018.xml
#
#          pravilnik o pograničnoj propusnici i dozvoli za jednokratni prijelaz zajedničke državne granice  \
# title     pravilnik o pograničnoj propusnici i dozvoli z...
# text       \nMINISTARSTVO UNUTARNJIH POSLOVA\n1710\nNa t...
# labels                                   [2168, 4722, 1964]
# filename                                       NN043907.xml
#
#          pravilnik o metodologiji za izračun i određivanje okvirnog cilja ušteda energije u neposrednoj potrošnji  \
# title     pravilnik o metodologiji za izračun i određiva...
# text       \nMINISTARSTVO GOSPODARSTVA, RADA I PODUZETNI...
# labels                                        [1715, 33269]
# filename                                       NN035080.xml
#
#          odluka o davanju suglasnosti na financijski plan hrvatskog fonda za privatizaciju za 2007. godinu  \
# title     odluka o davanju suglasnosti na financijski pl...
# text      HRVATSKI SABOR\n3103\nNa temelju članka 24. Za...
# labels                                               [4667]
# filename                                       NN024977.xml
#
#          pravilnik o mjeriteljskim zahtjevima za mjerila brzine vozila u cestovnome prometu  \
# title     pravilnik o mjeriteljskim zahtjevima za mjeril...
# text       \nDRŽAVNI ZAVOD ZA NORMIZACIJU I MJERITELJSTV...
# labels                             [5960, 2563, 3596, 4150]
# filename                                       NN003286.xml
#
#                                         zakon o kazalištima  \
# title                                   zakon o kazalištima
# text      HRVATSKI SABOR\n1703\nNa temelju članka 88. Us...
# labels                       [33133, 1325, 2938, 829, 4415]
# filename                                       NN023067.xml
#
#          pravilnik o uvjetima i načinu izdavanja i oduzimanja odobrenja za ambalažu za prijevoz radioaktivnih i nuklearnih materijala  \
# title     pravilnik o uvjetima i načinu izdavanja i oduz...
# text       \nDRŽAVNI ZAVOD ZA RADIOLOŠKU I NUKLEARNU SIG...
# labels                 [2784, 5127, 3216, 4374, 4150, 5566]
# filename                                       NN043255.xml
#
#          pravilnik o načinu provedbe zaštitnih mjera koje su zakonom o zaštiti od nasilja u obitelji stavljene u nadležnost policije
# title     pravilnik o načinu provedbe zaštitnih mjera ko...
# text       \nMINISTARSTVO UNUTARNJIH POSLOVA\n778\nNa te...
# labels                                        [33346, 5187]
# filename                                       NN004342.xml
#
# [4 rows x 10576 columns]

# %%
df_dataset.columns
# Out:
# Index(['odluka o usklađivanju novčanih naknada za tjelesno oštećenje od 1. siječnja 1990.',
#        'uredba o kriterijima za utvrđivanje korisnika i načinu raspodjele dijela prihoda od igara na sreću za 2011. godinu',
#        'odluka o davanju potpore za rast i razvoj malog gospodarstva',
#        'odluka o davanju suglasnosti na financijski plan za 1998. godinu hrvatskog zavoda za zdravstveno osiguranje',
#        'odluka o katastarskoj izmjeri na području grada visa za dio katastarske općine vis',
#        'odluka o visini dnevnice za službeno putovanje i visini naknada za korisnike koji se financiraju iz sredstava državnog proračuna',
#        'tehnički propis za betonske konstrukcije',
#        'odluka o određivanju osjetljivih područja',
#        'odluka o diskontnoj (eskontnoj) stopi hrvatske narodne banke',
#        'odluka o davanju suglasnosti na financijski plan agencije za upravljanje državnom imovinom za 2013. godinu i projekcije za 2014. i 2015. godinu',
#        ...
#        'ugovor između vlade republike hrvatske i židovske vjerske zajednice bet israel u hrvatskoj o pitanjima od zajedničkog interesa',
#        'metodološke osnove za prikupljanje podataka u statistici mlijeka i mliječnih proizvoda',
#        'odluka o programu i načinu provjere stručne osposobljenosti nadzornika koji obavljaju poslove kontrole osovinskog opterećenja, ukupne mase i dimenzija vozila u prometu na cestama',
#        'pravilnik o pograničnoj propusnici i dozvoli za jednokratni prijelaz zajedničke državne granice',
#        'pravilnik o metodologiji za izračun i određivanje okvirnog cilja ušteda energije u neposrednoj potrošnji',
#        'odluka o davanju suglasnosti na financijski plan hrvatskog fonda za privatizaciju za 2007. godinu',
#        'pravilnik o mjeriteljskim zahtjevima za mjerila brzine vozila u cestovnome prometu',
#        'zakon o kazalištima',
#        'pravilnik o uvjetima i načinu izdavanja i oduzimanja odobrenja za ambalažu za prijevoz radioaktivnih i nuklearnih materijala',
#        'pravilnik o načinu provedbe zaštitnih mjera koje su zakonom o zaštiti od nasilja u obitelji stavljene u nadležnost policije'],
#       dtype='object', length=10576)

# %%
df_dataset['odluka o usklađivanju novčanih naknada za tjelesno oštećenje od 1. siječnja 1990.']
# Out:
# title       odluka o usklađivanju novčanih naknada za tjel...
# text        SAMOUPRAVNA INTERESNA ZAJEDNICA MIROVINSKOG I ...
# labels                                           [3562, 1436]
# filename                                         NN034535.xml
# Name: odluka o usklađivanju novčanih naknada za tjelesno oštećenje od 1. siječnja 1990., dtype: object
